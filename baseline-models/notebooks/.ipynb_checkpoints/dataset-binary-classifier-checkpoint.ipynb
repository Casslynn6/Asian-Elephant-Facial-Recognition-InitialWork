# %% [markdown]
# ## Generate Data : Binary Classifier

# %%
import os
import itertools
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
import imageio
import pandas as pd
from tqdm import tqdm

# %matplotlib inline

plt.style.use("bmh")

# %%
#!pip install Image

# %%
original_data_path = '../data/original'
filepaths = [os.path.join(original_data_path, f) for f in os.listdir(original_data_path) if f!='.DS_Store']

filepaths
# Out:
# ['../data/original/Columbus Zoo',
#  '../data/original/Cincinnati Zoo',
#  '../data/original/National Zoo',
#  '../data/original/Clean']

# %%
include_folders = ['../data/original/National Zoo',
 '../data/original/Cincinnati Zoo',
 '../data/original/Columbus Zoo']

# %% [markdown]
# ## Labels

# %%
data_folders = include_folders
labels = []

def get_labels(foldername):
    labels = [f for f in os.listdir(foldername)]
    return labels

# %%
values = map(get_labels, data_folders)
labels.extend(values)
labels = list(itertools.chain(*labels))

# %%
labels
# Out:
# ['Spike',
#  'Swarna',
#  'Kamala',
#  'Maharani',
#  'Schottzie',
#  'Sabu',
#  'Jati',
#  'MyThai',
#  'Sunny',
#  'Connie',
#  'Rudy',
#  'Beco',
#  'Pheobe',
#  'Hank']

# %%
print(f" Labels: {labels}, \n No of labels:{len(labels)}")
# Out:
#  Labels: ['Spike', 'Swarna', 'Kamala', 'Maharani', 'Schottzie', 'Sabu', 'Jati', 'MyThai', 'Sunny', 'Connie', 'Rudy', 'Beco', 'Pheobe', 'Hank'],
#  No of labels:14

# %% [markdown]
# ### All Images

# %%
data = {}
data['filepath']=[]
data['image']=[]
data['imagename'] = []
data['label'] = []
data["extension"] = []

extension = set()
empty_files = set()

for image_folder in data_folders:
    for (dirpath, dirnames, filenames) in os.walk(image_folder):
        if dirnames == ".DS_Store":
            continue
            
        for f in tqdm(filenames):
            
            if f == ".DS_Store":
                continue
            
            ## check image
            size = os.stat(os.path.join(dirpath,f)).st_size
            
            if size == 0:
                empty_files.add(os.path.join(dirpath,f))
                continue
                
            ## found two images - odd images - Hank_IMG_6061.JPG, Connie_IMG_3589
            label = os.path.basename(dirpath)
            imagename = f"{label}_{f}"
            
            
            
            if imagename in ['Connie_IMG_3589.JPG','Hank_IMG_6061.JPG']:
                print("Ignoring image ",imagename)
                continue
            
            filename, file_extension = os.path.splitext(f)
            
            ## check image files
            if file_extension==".JPG":
                img = cv2.imread(os.path.join(dirpath, f))
                if img is None:
                    continue
            
                if len(img.shape)!=3:
                    print(img.shape)
                    continue
                    
            data["extension"].append(file_extension)
            data['label'].append(label)
            data['image'].append(f)
            data['imagename'].append(imagename)
            data['filepath'].append(os.path.join(dirpath, f))
# Out:
# 0it [00:00, ?it/s]
# 100%|██████████| 1271/1271 [05:19<00:00,  3.92it/s]
# 100%|██████████| 1553/1553 [06:14<00:00,  3.74it/s]
# 100%|██████████| 1066/1066 [05:11<00:00,  3.21it/s]
#  69%|██████▉   | 880/1276 [04:14<02:08,  3.09it/s]

# %%
df = pd.DataFrame(data)

# %%
print(f" No of files found: {df.shape[0]}")
# Out:
#  No of files found: 19182

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df["extension"].value_counts()
# Out:
# .JPG    18136
# .MOV     1045
# .AAE        1
# Name: extension, dtype: int64

# %%
df["extension"].value_counts().plot(kind="bar")

# %%
print(f"No of empty files: {len(empty_files)}")
# Out:
# No of empty files: 1

# %% [markdown]
# ### Resize and copy to the folder

# %%
## resize:

## Create images from mov files
dim = (227, 227)
def getFrame(vidcap,sec,path):
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000)
    hasFrames,image = vidcap.read()
    if hasFrames:
        print('Original Dimensions : ',image.shape)
        resized = cv2.resize(image, dim, interpolation=cv2.INTER_LINEAR)
        cv2.imwrite(path, resized)     # save frame as JPG file
    return hasFrames

def get_images(save_path, video_file_path,filename):
    frameRate = 0.5 # capture image in each 0.5 second
    image_write_path  = lambda count: os.path.join(save_path,"%s_frame%d.jpg" % (filename,count))
    count=1
    sec = 0
    vidcap = cv2.VideoCapture(video_file_path)
    success = getFrame(vidcap,sec,image_write_path(count))
    while success:
        count = count + 1
        sec = sec + frameRate
        sec = round(sec, 2)
        success = getFrame(vidcap,sec,image_write_path(count))
        
        
def resize_image(imgpath,savepath):
    img = cv2.imread(imgpath, cv2.IMREAD_UNCHANGED)
    
    # resize image
    resized = cv2.resize(img, dim,interpolation=cv2.INTER_LINEAR)
    cv2.imwrite(savepath, resized)
    return

# %%
save_path = os.path.join("../data/binary-classifier/")
def save_images(df):
    for idx, row in df.iterrows():
        extension = row["extension"]
        current_file_path = row["filepath"]
        label = row["label"]
        newimagename = row["imagename"]
        print(f"Index: {idx}")
        if extension==".MOV":
            ## get frame and resize and save
            get_images(save_path, current_file_path,newimagename)
        elif extension==".JPG":
            #print(current_file_path)
            resize_image(current_file_path, os.path.join(save_path,newimagename))  
        else:
            print(current_file_path)
            continue

# %%
save_images(df)
# Out:
# Index: 0
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5
# Index: 6
# Index: 7
# Index: 8
# Index: 9
# Index: 10
# Index: 11
# Index: 12
# Index: 13
# Index: 14
# Index: 15
# Index: 16
# Index: 17
# Index: 18
# Index: 19
# Index: 20
# Index: 21
# Index: 22
# Index: 23
# Index: 24
# Index: 25
# Index: 26
# Index: 27
# Index: 28
# Index: 29
# Index: 30
# Index: 31
# Index: 32
# Index: 33
# Index: 34
# Index: 35
# Index: 36
# Index: 37
# Index: 38
# Index: 39
# Index: 40
# Index: 41
# Index: 42
# Index: 43
# Index: 44
# Index: 45
# Index: 46
# Index: 47
# Index: 48
# Index: 49
# Index: 50
# Index: 51
# Index: 52
# Index: 53
# Index: 54
# Index: 55
# Index: 56
# Index: 57
# Index: 58
# Index: 59
# Index: 60
# Index: 61
# Index: 62
# Index: 63
# Index: 64
# Index: 65
# Index: 66
# Index: 67
# Index: 68
# Index: 69
# Index: 70
# Index: 71
# Index: 72
# Index: 73
# Index: 74
# Index: 75
# Index: 76
# Index: 77
# Index: 78
# Index: 79
# Index: 80
# Index: 81
# Index: 82
# Index: 83
# Index: 84
# Index: 85
# Index: 86
# Index: 87
# Index: 88
# Index: 89
# Index: 90
# Index: 91
# Index: 92
# Index: 93
# Index: 94
# Index: 95
# Index: 96
# Index: 97
# Index: 98
# Index: 99
# Index: 100
# Index: 101
# Index: 102
# Index: 103
# Index: 104
# Index: 105
csv_df.to_csv(os.path.join(save_path,"binary_classifier_imagepaths.csv"),index=False)

# %%
csv_df.head()
# Out:
#                              path
# 0             Pheobe_IMG_5409.JPG
# 1             Pheobe_IMG_5460.JPG
# 2  Pheobe_IMG_3734.MOV_frame3.jpg
# 3           Maharani_IMG_3575.JPG
# 4               Hank_IMG_7264.JPG

# %%
df = pd.read_csv(os.path.join(save_path,"binary_classifier_imagepaths.csv"))

# %%
df
# Out:
#                                  path
# 0                 Pheobe_IMG_5409.JPG
# 1                 Pheobe_IMG_5460.JPG
# 2      Pheobe_IMG_3734.MOV_frame3.jpg
# 3               Maharani_IMG_3575.JPG
# 4                   Hank_IMG_7264.JPG
# 5                   Rudy_IMG_0842.JPG
# 6                   Rudy_IMG_1252.JPG
# 7                   Sabu_IMG_4245.JPG
# 8                 Connie_IMG_2998.JPG
# 9                   Jati_IMG_2677.JPG
# 10                Swarna_IMG_8859.JPG
# 11                Connie_IMG_2127.JPG
# 12       Rudy_IMG_0725.MOV_frame2.jpg
# 13                Swarna_IMG_9805.JPG
# 14              Maharani_IMG_3496.JPG
# 15                  Beco_IMG_7657.JPG
# 16                 Spike_IMG_0240.JPG
# 17                Connie_IMG_3247.JPG
# 18                Swarna_IMG_9539.JPG
# 19                MyThai_IMG_3877.JPG
# 20                  Hank_IMG_7936.JPG
# 21              Maharani_IMG_3691.JPG
# 22                Connie_IMG_2250.JPG
# 23                Connie_IMG_3138.JPG
# 24                  Rudy_IMG_1454.JPG
# 25                  Rudy_IMG_1015.JPG
# 26      Sunny_IMG_9084.MOV_frame2.jpg
# 27     Pheobe_IMG_3716.MOV_frame2.jpg
# 28                Pheobe_IMG_4165.JPG
# 29                Kamala_IMG_2134.JPG
# ...                               ...
# 19403             Swarna_IMG_9602.JPG
# 19404               Hank_IMG_6553.JPG
# 19405              Spike_IMG_0387.JPG
# 19406               Rudy_IMG_0597.JPG
# 19407              Spike_IMG_0169.JPG
# 19408             Pheobe_IMG_5138.JPG
# 19409             Pheobe_IMG_5276.JPG
# 19410               Jati_IMG_3220.JPG
# 19411             Connie_IMG_3313.JPG
# 19412             Connie_IMG_2467.JPG
# 19413              Sunny_IMG_9413.JPG
# 19414             Swarna_IMG_8840.JPG
# 19415               Rudy_IMG_0063.JPG
# 19416               Hank_IMG_8001.JPG
# 19417               Beco_IMG_7626.JPG
# 19418  Connie_IMG_3041.MOV_frame1.jpg
# 19419             Pheobe_IMG_5149.JPG
# 19420              Sunny_IMG_9066.JPG
# 19421  Connie_IMG_3546.MOV_frame3.jpg
# 19422             Kamala_IMG_2331.JPG
# 19423             Pheobe_IMG_3963.JPG
# 19424               Sabu_IMG_4411.JPG
# 19425               Hank_IMG_7973.JPG
# 19426           Maharani_IMG_3515.JPG
# 19427              Spike_IMG_0146.JPG
# 19428               Sabu_IMG_4727.JPG
# 19429             Pheobe_IMG_4718.JPG
# 19430             Connie_IMG_1748.JPG
# 19431               Hank_IMG_6638.JPG
# 19432           Maharani_IMG_2591.JPG
#
# [19433 rows x 1 columns]

# %%
import torch
x = torch.tensor(1)

# %%
x
# Out:
# tensor(1)
